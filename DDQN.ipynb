# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython import display

def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
    
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    
    anim.save('movie_cartpole_DQN.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
from collections import namedtuple

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.99
MAX_STEPS = 200
NUM_EPISODES = 500

# %%
class ReplayMemory:
    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0
    
    def push(self, state, action, state_next, reward):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        
        self.memory[self.index] = Transition(state, action, state_next, reward)
        
        self.index = (self.index + 1) % self.capacity
    
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        self.memory = ReplayMemory(CAPACITY)
        
        self.model = nn.Sequential()
        self.model.add_module('fc1', nn.Linear(num_states, 32))
        self.model.add_module('relu1', nn.ReLU())
        self.model.add_module('fc2', nn.Linear(32, 32))
        self.model.add_module('relu2', nn.ReLU())
        self.model.add_module('fc3', nn.Linear(32, num_actions))
        print(self.model)
        
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)
    
    def replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        
        transitions = self.memory.sample(BATCH_SIZE)
        batch = Transition(*zip(*transitions))
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
        
        self.model.eval()
        state_action_values = self.model(state_batch).gather(1, action_batch)
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.next_state)))
        next_state_values = torch.zeros(BATCH_SIZE)
        next_state_values[non_final_mask] = self.model(non_final_next_states).max(1)[0].detach()
        expected_state_action_values = reward_batch + GAMMA * next_state_values
        
        self.model.train()
        loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
    
    def decide_action(self, state, episode):
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            self.model.eval()
            with torch.no_grad():
                action = self.model(state).max(1)[1].view(1, 1)
        else:
            action = torch.LongTensor([[random.randrange(self.num_actions)]])
        
        return action

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
    
    def update_Q_function(self):
        self.brain.replay()
    
    def get_action(self, state, episode):
        action = self.brain.decide_action(state, episode)
        return action
    
    def memorize(self, state, action, state_next, reward):
        self.brain.memory.push(state, action, state_next, reward)

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        self.num_status = self.env.observation_space.shape[0]
        self.num_actions = self.env.action_space.n
        self.agent = Agent(self.num_status, self.num_actions)
    
    def run(self):
        episode_10_list = np.zeros(10)
        
        complete_episodes = 0
        is_episode_final = False
        frames = []
        
        for episode in range(NUM_EPISODES):
            observation = self.env.reset()
            
            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)
            
            for step in range(MAX_STEPS):
                if is_episode_final is True:
                    frames.append(self.env.render(mode='rgb_array'))
                
                action = self.agent.get_action(state, episode)
                
                observation_next, _, done, _ = self.env.step(action.item())
                
                if done:
                    state_next = None
                    
                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))
                    
                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else:
                        reward = torch.FloatTensor([1.0])
                        complete_episodes += 1
                else:
                    reward = torch.FloatTensor([0.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)
                
                self.agent.memorize(state, action, state_next, reward)
                
                self.agent.update_Q_function()
                
                state = state_next
                
                if done:
                    print('%d Episode: Finished after %d steps: 10 average = %.1lf' % (episode, step + 1, episode_10_list.mean()))
                    break
            
            if is_episode_final is True:
                display_frames_as_gif(frames)
                break
            
            if complete_episodes >= 10:
                print('10回連続成功')
                is_episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Sequential(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 10 steps: 10 average = 1.0
# 1 Episode: Finished after 10 steps: 10 average = 2.0
# 2 Episode: Finished after 10 steps: 10 average = 3.0
# 3 Episode: Finished after 9 steps: 10 average = 3.9
# 4 Episode: Finished after 10 steps: 10 average = 4.9
# 5 Episode: Finished after 10 steps: 10 average = 5.9
# 6 Episode: Finished after 9 steps: 10 average = 6.8
# 7 Episode: Finished after 8 steps: 10 average = 7.6
# 8 Episode: Finished after 10 steps: 10 average = 8.6
# 9 Episode: Finished after 8 steps: 10 average = 9.4
# 10 Episode: Finished after 9 steps: 10 average = 9.3
# 11 Episode: Finished after 12 steps: 10 average = 9.5
# 12 Episode: Finished after 9 steps: 10 average = 9.4
# 13 Episode: Finished after 10 steps: 10 average = 9.5
# 14 Episode: Finished after 11 steps: 10 average = 9.6
# 15 Episode: Finished after 13 steps: 10 average = 9.9
# 16 Episode: Finished after 32 steps: 10 average = 12.2
# 17 Episode: Finished after 49 steps: 10 average = 16.3
# 18 Episode: Finished after 60 steps: 10 average = 21.3
# 19 Episode: Finished after 35 steps: 10 average = 24.0
# 20 Episode: Finished after 62 steps: 10 average = 29.3
# 21 Episode: Finished after 84 steps: 10 average = 36.5
# 22 Episode: Finished after 23 steps: 10 average = 37.9
# 23 Episode: Finished after 30 steps: 10 average = 39.9
# 24 Episode: Finished after 26 steps: 10 average = 41.4
# 25 Episode: Finished after 32 steps: 10 average = 43.3
# 26 Episode: Finished after 36 steps: 10 average = 43.7
# 27 Episode: Finished after 25 steps: 10 average = 41.3
# 28 Episode: Finished after 22 steps: 10 average = 37.5
# 29 Episode: Finished after 23 steps: 10 average = 36.3
# 30 Episode: Finished after 24 steps: 10 average = 32.5
# 31 Episode: Finished after 26 steps: 10 average = 26.7
# 32 Episode: Finished after 29 steps: 10 average = 27.3
# 33 Episode: Finished after 18 steps: 10 average = 26.1
# 34 Episode: Finished after 26 steps: 10 average = 26.1
# 35 Episode: Finished after 17 steps: 10 average = 24.6
# 36 Episode: Finished after 26 steps: 10 average = 23.6
# 37 Episode: Finished after 19 steps: 10 average = 23.0
# 38 Episode: Finished after 17 steps: 10 average = 22.5
# 39 Episode: Finished after 25 steps: 10 average = 22.7
# 40 Episode: Finished after 21 steps: 10 average = 22.4
# 41 Episode: Finished after 19 steps: 10 average = 21.7
# 42 Episode: Finished after 16 steps: 10 average = 20.4
# 43 Episode: Finished after 20 steps: 10 average = 20.6
# 44 Episode: Finished after 18 steps: 10 average = 19.8
# 45 Episode: Finished after 19 steps: 10 average = 20.0
# 46 Episode: Finished after 16 steps: 10 average = 19.0
# 47 Episode: Finished after 22 steps: 10 average = 19.3
# 48 Episode: Finished after 17 steps: 10 average = 19.3
# 49 Episode: Finished after 21 steps: 10 average = 18.9
# 50 Episode: Finished after 19 steps: 10 average = 18.7
# 51 Episode: Finished after 51 steps: 10 average = 21.9
# 52 Episode: Finished after 15 steps: 10 average = 21.8
# 53 Episode: Finished after 16 steps: 10 average = 21.4
# 54 Episode: Finished after 200 steps: 10 average = 39.6
# 55 Episode: Finished after 42 steps: 10 average = 41.9
# 56 Episode: Finished after 63 steps: 10 average = 46.6
# 57 Episode: Finished after 200 steps: 10 average = 64.4
# 58 Episode: Finished after 77 steps: 10 average = 70.4
# 59 Episode: Finished after 102 steps: 10 average = 78.5
# 60 Episode: Finished after 50 steps: 10 average = 81.6
# 61 Episode: Finished after 60 steps: 10 average = 82.5
# 62 Episode: Finished after 128 steps: 10 average = 93.8
# 63 Episode: Finished after 100 steps: 10 average = 102.2
# 64 Episode: Finished after 60 steps: 10 average = 88.2
# 65 Episode: Finished after 87 steps: 10 average = 92.7
# 66 Episode: Finished after 97 steps: 10 average = 96.1
# 67 Episode: Finished after 51 steps: 10 average = 81.2
# 68 Episode: Finished after 81 steps: 10 average = 81.6
# 69 Episode: Finished after 55 steps: 10 average = 76.9
# 70 Episode: Finished after 143 steps: 10 average = 86.2
# 71 Episode: Finished after 75 steps: 10 average = 87.7
# 72 Episode: Finished after 59 steps: 10 average = 80.8
# 73 Episode: Finished after 98 steps: 10 average = 80.6
# 74 Episode: Finished after 142 steps: 10 average = 88.8
# 75 Episode: Finished after 144 steps: 10 average = 94.5
# 76 Episode: Finished after 152 steps: 10 average = 100.0
# 77 Episode: Finished after 129 steps: 10 average = 107.8
# 78 Episode: Finished after 131 steps: 10 average = 112.8
# 79 Episode: Finished after 145 steps: 10 average = 121.8
# 80 Episode: Finished after 198 steps: 10 average = 127.3
# 81 Episode: Finished after 200 steps: 10 average = 139.8
# 82 Episode: Finished after 200 steps: 10 average = 153.9
# 83 Episode: Finished after 200 steps: 10 average = 164.1
# 84 Episode: Finished after 200 steps: 10 average = 169.9
# 85 Episode: Finished after 200 steps: 10 average = 175.5
# 86 Episode: Finished after 200 steps: 10 average = 180.3
# 87 Episode: Finished after 200 steps: 10 average = 187.4
# 88 Episode: Finished after 200 steps: 10 average = 194.3
# 89 Episode: Finished after 200 steps: 10 average = 199.8
# 10回連続成功
# 90 Episode: Finished after 200 steps: 10 average = 200.0
